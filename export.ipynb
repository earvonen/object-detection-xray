# %%
from ultralytics import YOLO
from openvino.tools.mo import convert_model

model = YOLO("runs-openshift/exp1/weights/best.pt")

# Export to ONNX (best for OpenVINO)
onnx_path = model.export(format="onnx")  


ov_ir_path = convert_model(
    onnx_path,
    compress_to_fp16=True,
    model_name="yolo-openvino"
)
# Out:
# Ultralytics 8.3.231 🚀 Python-3.12.9 torch-2.7.1+cu128 CPU (AMD EPYC 7742 64-Core Processor)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs-openshift/exp1/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnxslim>=0.1.71'] not found, attempting AutoUpdate...
# Using Python 3.12.9 environment at: /opt/app-root
# Resolved 10 packages in 199ms
# Prepared 1 package in 16ms
# Installed 1 package in 8ms
#  + onnxslim==0.1.75
#
# requirements: AutoUpdate success ✅ 0.3s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.19.0 opset 19...
# ONNX: slimming with onnxslim 0.1.75...
# ONNX: export success ✅ 2.1s, saved as 'runs-openshift/exp1/weights/best.onnx' (11.7 MB)
#
# Export complete (2.4s)
# Results saved to /opt/app-root/src/runs-openshift/exp1/weights
# Predict:         yolo predict task=detect model=runs-openshift/exp1/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs-openshift/exp1/weights/best.onnx imgsz=640 data=images/data.yaml
# Visualize:       https://netron.app
# [ INFO ] MO command line tool is considered as the legacy conversion API as of OpenVINO 2023.2 release.
# In 2025.0 MO command line tool and openvino.tools.mo.convert_model() will be removed. Please use OpenVINO Model Converter (OVC) or openvino.convert_model(). OVC represents a lightweight alternative of MO and provides simplified model conversion API.
# Find more information about transition from MO to OVC at https://docs.openvino.ai/2023.2/openvino_docs_OV_Converter_UG_prepare_model_convert_model_MO_OVC_transition.html
