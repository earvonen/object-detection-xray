# %%
from ultralytics import YOLO

model = YOLO("runs-openshift/exp1/weights/best.pt")
results = model("knife.jpg")
results[0].show()
# Out:
# image 1/1 /opt/app-root/src/knife.jpg: 640x640 1 0, 5.6ms
# Speed: 1.9ms preprocess, 5.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>
